# %%
import pandas as pd
import re
import plotly.graph_objects as go
#import yfinance as yf
import numpy as np
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import nltk
import skopt
import joblib
#import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from tqdm import tqdm
import pymorphy2

# %%
data = pd.read_csv('USDRUB_Days.csv', parse_dates=['<DATE>'])
data.columns = ['TICKER','PER','date','time','Close']
data['Close1']=data['Close'].shift(-1)
data['target']=np.sign(data['Close1']-data['Close'])
data.reset_index(drop=True, inplace=True)
target=data[['date', 'target']]
target['key_date'] = target['date'].dt.strftime('%Y-%m-%d')
target=target.loc[target['date']<'2021']
target
# Out:
# <ipython-input-42-7c26bc5ad021>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target['key_date'] = target['date'].dt.strftime('%Y-%m-%d')
#            date  target    key_date
# 0    2016-01-01     0.0  2016-01-01
# 1    2016-01-02     1.0  2016-01-02
# 2    2016-01-03    -1.0  2016-01-03
# 3    2016-01-04     1.0  2016-01-04
# 4    2016-01-05     1.0  2016-01-05
# ...         ...     ...         ...
# 1745 2020-12-27    -1.0  2020-12-27
# 1746 2020-12-28     1.0  2020-12-28
# 1747 2020-12-29     1.0  2020-12-29
# 1748 2020-12-30    -1.0  2020-12-30
# 1749 2020-12-31     1.0  2020-12-31
#
# [1750 rows x 3 columns]

# %%
df=pd.read_csv('VBR_new.csv', encoding='utf-16')
df = df[df['tweet'].notna()]
df.reset_index(drop=True, inplace=True)
df['date']=pd.to_datetime(df['date'])
def clean(sen):
    sentence = re.sub("(http|https|ftp)\://([a-zA-Z0-9\-\.]+\.+[a-zA-Z]{2,3})(:[a-zA-Z0-9]*)?/?([a-zA-Z0-9\-\._\?\,\'/\\\+&amp;%\$#\=~]*)[^\.\,\)\(\s]?", ' ', sen)
    sentence = re.sub('[^a-zA-Zа-яА-Яё]', ' ', sentence)
    sentence = re.sub(r'\s+[a-zA-Z]\s+', ' ', sentence)
    sentence = re.sub(r'\s+', ' ', sentence)
    sentence = sentence.strip()
    sentence = sentence.lower()
    return sentence
df['tweet'] = df['tweet'].apply(clean)
df['key_date'] = df['date'].dt.strftime('%Y-%m-%d')
df = pd.merge(df,target[['key_date','target']], on='key_date', how='left')
df = df[df['target'].notna()]
df = df.loc[df['target']!=0]
data = data.loc[data['target']!=0]

# %%
df.to_csv('clean_tweets.csv', index=False)

# %%
df_lem = df.copy()
morph = pymorphy2.MorphAnalyzer()
def lemmatize(text):
    words = nltk.word_tokenize(text)
    res = []
    for word in words:
        p = morph.parse(word)[0]
        res.append(p.normal_form)
    return ' '.join(res)

tqdm.pandas()
df_lem['tweet'] = df_lem['tweet'].progress_apply(lemmatize)
# Out:
# 100%|██████████| 81316/81316 [03:20<00:00, 406.50it/s]

# %%
df_lem.to_csv('clean_tweets_lem.csv', index=False)

# %%
y_train = list(df.loc[df['date']<'2020-10-01','target'])
y_test = list(df.loc[df['date']>='2020-10-01','target'])
X_train = list(df.loc[df['date']<'2020-10-01','tweet'])
X_test = list(df.loc[df['date']>='2020-10-01','tweet'])

y_train_lem = list(df_lem.loc[df_lem['date']<'2020-10-01','target'])
y_test_lem = list(df_lem.loc[df_lem['date']>='2020-10-01','target'])
X_train_lem = list(df_lem.loc[df_lem['date']<'2020-10-01','tweet'])
X_test_lem = list(df_lem.loc[df_lem['date']>='2020-10-01','tweet'])

target=target.loc[target['date']<'2021']
target_test=target.loc[target['date']>='2020-10-01']
target_test.reset_index(drop=True, inplace=True)
day_y_test=list(target.loc[target['date']>='2020-10-01','target'])
day_y_test=day_y_test[:-1]
day_x_test=[]
day_x_test_lem=[]
for i in range(1,len(day_y_test)):
    day_x_test.append(df.loc[(df['date']<target_test.loc[i,'key_date']) & (df['date']>=target_test.loc[i-1,'key_date'])])
    day_x_test_lem.append(df_lem.loc[(df_lem['date']<target_test.loc[i,'key_date']) & (df_lem['date']>=target_test.loc[i-1,'key_date'])])

# %%
stopwords=nltk.corpus.stopwords.words('russian')

# %%
def metric(proba):
    respred = 0
    resproba = 0
    for i in proba:
        respred+=np.sign(i[1]-i[0])
        resproba+=2*i[1]
    resproba=resproba/len(proba)-1
    respred=respred/len(proba)
    return respred, resproba


def mod_construct(lem=False,tfidf=False,ngram_range='13',stop_words=False,max_features=None,
                  penalty='l2',fit_intercept=True,class_weight='balanced',C=1,res='score'):
    ngram_range = [int(ngram_range[0]), int(ngram_range[1])]
    if stop_words:
        stop_words=stopwords
    else:
        stop_words=None
    if tfidf:
        vec = TfidfVectorizer(ngram_range=ngram_range, stop_words=stop_words, max_features=max_features)
    else:
        vec = CountVectorizer(ngram_range=ngram_range, stop_words=stop_words, max_features=max_features)
    if lem:
        X = X_train_lem
        y = y_train_lem.copy()
        day_x = day_x_test_lem
    else:
        X = X_train
        y = y_train.copy()
        day_x = day_x_test
    X = vec.fit_transform(X)
    model = LogisticRegression(penalty=penalty, fit_intercept=fit_intercept, class_weight=class_weight, C=C,
                               random_state=42, solver='liblinear', max_iter=500)
    model.fit(X,y)
    day_test_predict = []
    respred_ac=0
    resproba_ac=0
    n=0
    zero=0
    for i in day_x:
        if len(i)>=20:
            buf_x = vec.transform(i['tweet'])
            buf_proba = model.predict_proba(buf_x)
            buf_day_pred = metric(buf_proba)
            if np.sign(buf_day_pred[0])==day_y_test[n]:
                respred_ac+=1
            if np.sign(buf_day_pred[1])==day_y_test[n]:
                resproba_ac+=1
            day_test_predict.append((n,buf_day_pred))
        else:
            zero+=1
        n+=1

    respred_ac = respred_ac/(len(day_x)-zero)
    resproba_ac = resproba_ac/(len(day_x)-zero)
    f1 = f1_score(y_test, model.predict(vec.transform(X_test)))
    print(f1, respred_ac, resproba_ac)
    if res=='score':
        return -max(respred_ac, resproba_ac)
    elif res=='model':
        return vec, model

# %%
SPACE = [
    skopt.space.Categorical([False, True], name='lem'),
    skopt.space.Categorical([False, True], name='tfidf'),
    skopt.space.Categorical(['11','12','13','22','23','33'], name='ngram_range'),
    skopt.space.Categorical([False, True], name='stop_words'),
    skopt.space.Categorical([50000,100000,None], name='max_features'),
    skopt.space.Categorical([False, True], name='fit_intercept'),
    skopt.space.Categorical([None, 'balanced'], name='class_weight'),
    skopt.space.Real(0.0001, 50, name='C')
]

@skopt.utils.use_named_args(SPACE)
def objective(**params):
    return mod_construct(**params)

result = skopt.gp_minimize(objective, SPACE, n_calls=400, n_random_starts=200, n_jobs=-1, verbose=True)
best_metric = result.fun
best_param = result.x
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# 0.4921077065923862 0.42028985507246375 0.4492753623188406
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 4.3916
# Function value obtained: -0.4493
# Current minimum: -0.4493
# Iteration No: 2 started. Evaluating function at random point.
# 0.49696969696969695 0.4782608695652174 0.5217391304347826
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 5.2948
# Function value obtained: -0.5217
# Current minimum: -0.5217
# Iteration No: 3 started. Evaluating function at random point.
# 0.42105263157894735 0.5362318840579711 0.4782608695652174
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 3.0562
# Function value obtained: -0.5362
# Current minimum: -0.5362
# Iteration No: 4 started. Evaluating function at random point.
# 0.4987025241802312 0.5362318840579711 0.5507246376811594
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 2.3382
# Function value obtained: -0.5507
# Current minimum: -0.5507
# Iteration No: 5 started. Evaluating function at random point.
# 0.495114006514658 0.4927536231884058 0.36231884057971014
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 10.4689
# Function value obtained: -0.4928
# Current minimum: -0.5507
# Iteration No: 6 started. Evaluating function at random point.
# 0.520968439256377 0.43478260869565216 0.43478260869565216
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 3.0839
# Function value obtained: -0.4348
# Current minimum: -0.5507
# Iteration No: 7 started. Evaluating function at random point.
# 0.28551236749116604 0.4782608695652174 0.5217391304347826
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 4.5923
# Function value obtained: -0.5217
# Current minimum: -0.5507
# Iteration No: 8 started. Evaluating function at random point.
# 0.4974477958236659 0.463768115942029 0.463768115942029
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 9.0559
# Function value obtained: -0.4638
# Current minimum: -0.5507
# Iteration No: 9 started. Evaluating function at random point.
# 0.48112543962485343 0.36231884057971014 0.4492753623188406
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 5.2555
# Function value obtained: -0.4493
# Current minimum: -0.5507
# Iteration No: 10 started. Evaluating function at random point.
# 0.485414235705951 0.391304347826087 0.391304347826087
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 4.9407
# Function value obtained: -0.3913
# Current minimum: -0.5507
# Iteration No: 11 started. Evaluating function at random point.
# 0.5847457627118644 0.463768115942029 0.43478260869565216
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 5.7952
# Function value obtained: -0.4638
# Current minimum: -0.5507
# Iteration No: 12 started. Evaluating function at random point.
# 0.49191685912240185 0.36231884057971014 0.43478260869565216
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 3.3766
# Function value obtained: -0.4348
# Current minimum: -0.5507
# Iteration No: 13 started. Evaluating function at random point.
# 0.4998833138856477 0.5072463768115942 0.5507246376811594
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 6.9917
# Function value obtained: -0.5507
# Current minimum: -0.5507
# Iteration No: 14 started. Evaluating function at random point.
# 0.5199032329008136 0.4782608695652174 0.5072463768115942
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 5.2702
# Function value obtained: -0.5072
# Current minimum: -0.5507
# Iteration No: 15 started. Evaluating function at random point.
# 0.49859287054409 0.42028985507246375 0.5217391304347826
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 5.0806
# Function value obtained: -0.5217
# Current minimum: -0.5507
# Iteration No: 16 started. Evaluating function at random point.
# 0.48509228584950315 0.4782608695652174 0.5652173913043478
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 3.4277
# Function value obtained: -0.5652
# Current minimum: -0.5652
# Iteration No: 17 started. Evaluating function at random point.
# 0.28153310104529616 0.36231884057971014 0.36231884057971014
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 5.1439
# Function value obtained: -0.3623
# Current minimum: -0.5652
# Iteration No: 18 started. Evaluating function at random point.
# 0.5041360294117647 0.43478260869565216 0.4927536231884058
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 8.8949
# Function value obtained: -0.4928
# Current minimum: -0.5652
# Iteration No: 19 started. Evaluating function at random point.
# 0.49213161659513593 0.5652173913043478 0.6376811594202898
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 2.4943
# Function value obtained: -0.6377
# Current minimum: -0.6377
# Iteration No: 20 started. Evaluating function at random point.
# 0.5047169811320754 0.5507246376811594 0.5362318840579711
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 8.2003
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 21 started. Evaluating function at random point.
# 0.4886578449905482 0.4927536231884058 0.5362318840579711
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 3.4184
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 22 started. Evaluating function at random point.
# 0.492617764237169 0.5217391304347826 0.5217391304347826
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 3.7300
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 23 started. Evaluating function at random point.
# 0.5521422797089733 0.43478260869565216 0.463768115942029
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 3.0360
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 24 started. Evaluating function at random point.
# 0.5740215541690301 0.4057971014492754 0.37681159420289856
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 3.9939
# Function value obtained: -0.4058
# Current minimum: -0.6377
# Iteration No: 25 started. Evaluating function at random point.
# 0.281347690170198 0.37681159420289856 0.34782608695652173
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 5.4767
# Function value obtained: -0.3768
# Current minimum: -0.6377
# Iteration No: 26 started. Evaluating function at random point.
# 0.5257932225339952 0.42028985507246375 0.463768115942029
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 5.5406
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 27 started. Evaluating function at random point.
# 0.5093531665539779 0.5217391304347826 0.5507246376811594
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 5.5656
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 28 started. Evaluating function at random point.
# 0.5069460259621953 0.5072463768115942 0.5507246376811594
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 11.8508
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 29 started. Evaluating function at random point.
# 0.5042095416276894 0.5362318840579711 0.5362318840579711
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 9.2257
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 30 started. Evaluating function at random point.
# 0.49408424041646953 0.4927536231884058 0.5362318840579711
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 13.1527
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 31 started. Evaluating function at random point.
# 0.488421052631579 0.4492753623188406 0.4782608695652174
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 9.3139
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 32 started. Evaluating function at random point.
# 0.4896992659246981 0.4492753623188406 0.5072463768115942
# Iteration No: 32 ended. Evaluation done at random point.
# Time taken: 14.5350
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 33 started. Evaluating function at random point.
# 0.4835988753514527 0.43478260869565216 0.5072463768115942
# Iteration No: 33 ended. Evaluation done at random point.
# Time taken: 9.9256
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 34 started. Evaluating function at random point.
# 0.5027039736656478 0.5362318840579711 0.5072463768115942
# Iteration No: 34 ended. Evaluation done at random point.
# Time taken: 5.7926
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 35 started. Evaluating function at random point.
# 0.5072595281306715 0.4057971014492754 0.4057971014492754
# Iteration No: 35 ended. Evaluation done at random point.
# Time taken: 10.3898
# Function value obtained: -0.4058
# Current minimum: -0.6377
# Iteration No: 36 started. Evaluating function at random point.
# 0.5348094528422398 0.4492753623188406 0.463768115942029
# Iteration No: 36 ended. Evaluation done at random point.
# Time taken: 5.8125
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 37 started. Evaluating function at random point.
# 0.48531909730647904 0.5072463768115942 0.4782608695652174
# Iteration No: 37 ended. Evaluation done at random point.
# Time taken: 7.4440
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 38 started. Evaluating function at random point.
# 0.5782337852693294 0.42028985507246375 0.37681159420289856
# Iteration No: 38 ended. Evaluation done at random point.
# Time taken: 3.7484
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 39 started. Evaluating function at random point.
# 0.49476190476190485 0.5507246376811594 0.6231884057971014
# Iteration No: 39 ended. Evaluation done at random point.
# Time taken: 2.5879
# Function value obtained: -0.6232
# Current minimum: -0.6377
# Iteration No: 40 started. Evaluating function at random point.
# 0.48157709457873743 0.4492753623188406 0.43478260869565216
# Iteration No: 40 ended. Evaluation done at random point.
# Time taken: 4.1630
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 41 started. Evaluating function at random point.
# 0.5753931544865865 0.37681159420289856 0.36231884057971014
# Iteration No: 41 ended. Evaluation done at random point.
# Time taken: 6.0548
# Function value obtained: -0.3768
# Current minimum: -0.6377
# Iteration No: 42 started. Evaluating function at random point.
# 0.5825097892970352 0.463768115942029 0.4927536231884058
# Iteration No: 42 ended. Evaluation done at random point.
# Time taken: 5.2291
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 43 started. Evaluating function at random point.
# 0.5062771056836338 0.463768115942029 0.4782608695652174
# Iteration No: 43 ended. Evaluation done at random point.
# Time taken: 6.6339
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 44 started. Evaluating function at random point.
# 0.5130960376091337 0.5217391304347826 0.5072463768115942
# Iteration No: 44 ended. Evaluation done at random point.
# Time taken: 18.3491
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 45 started. Evaluating function at random point.
# 0.5326359832635983 0.4057971014492754 0.463768115942029
# Iteration No: 45 ended. Evaluation done at random point.
# Time taken: 6.7270
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 46 started. Evaluating function at random point.
# 0.489853044086774 0.4782608695652174 0.5217391304347826
# Iteration No: 46 ended. Evaluation done at random point.
# Time taken: 6.9511
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 47 started. Evaluating function at random point.
# 0.4994251552080937 0.4927536231884058 0.5072463768115942
# Iteration No: 47 ended. Evaluation done at random point.
# Time taken: 3.8693
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 48 started. Evaluating function at random point.
# 0.4882186616399623 0.5072463768115942 0.5362318840579711
# Iteration No: 48 ended. Evaluation done at random point.
# Time taken: 7.6799
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 49 started. Evaluating function at random point.
# 0.492478592918306 0.4057971014492754 0.4492753623188406
# Iteration No: 49 ended. Evaluation done at random point.
# Time taken: 4.9049
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 50 started. Evaluating function at random point.
# 0.29721362229102166 0.3333333333333333 0.42028985507246375
# Iteration No: 50 ended. Evaluation done at random point.
# Time taken: 7.8167
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 51 started. Evaluating function at random point.
# 0.48750000000000004 0.5797101449275363 0.5942028985507246
# Iteration No: 51 ended. Evaluation done at random point.
# Time taken: 16.3233
# Function value obtained: -0.5942
# Current minimum: -0.6377
# Iteration No: 52 started. Evaluating function at random point.
# 0.49187279151943464 0.5072463768115942 0.5507246376811594
# Iteration No: 52 ended. Evaluation done at random point.
# Time taken: 4.8616
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 53 started. Evaluating function at random point.
# 0.48455056179775274 0.34782608695652173 0.463768115942029
# Iteration No: 53 ended. Evaluation done at random point.
# Time taken: 3.1244
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 54 started. Evaluating function at random point.
# 0.48258124853869533 0.34782608695652173 0.4057971014492754
# Iteration No: 54 ended. Evaluation done at random point.
# Time taken: 5.4616
# Function value obtained: -0.4058
# Current minimum: -0.6377
# Iteration No: 55 started. Evaluating function at random point.
# 0.5102611940298507 0.42028985507246375 0.463768115942029
# Iteration No: 55 ended. Evaluation done at random point.
# Time taken: 18.1796
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 56 started. Evaluating function at random point.
# 0.4966932725199544 0.463768115942029 0.5217391304347826
# Iteration No: 56 ended. Evaluation done at random point.
# Time taken: 12.4380
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 57 started. Evaluating function at random point.
# 0.4993084370677731 0.43478260869565216 0.463768115942029
# Iteration No: 57 ended. Evaluation done at random point.
# Time taken: 6.1767
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 58 started. Evaluating function at random point.
# 0.5439381611065908 0.43478260869565216 0.43478260869565216
# Iteration No: 58 ended. Evaluation done at random point.
# Time taken: 4.3636
# Function value obtained: -0.4348
# Current minimum: -0.6377
# Iteration No: 59 started. Evaluating function at random point.
# 0.4935744883388862 0.5217391304347826 0.5942028985507246
# Iteration No: 59 ended. Evaluation done at random point.
# Time taken: 2.8862
# Function value obtained: -0.5942
# Current minimum: -0.6377
# Iteration No: 60 started. Evaluating function at random point.
# 0.4653836540864784 0.463768115942029 0.36231884057971014
# Iteration No: 60 ended. Evaluation done at random point.
# Time taken: 13.1200
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 61 started. Evaluating function at random point.
# 0.5133182844243792 0.5072463768115942 0.5652173913043478
# Iteration No: 61 ended. Evaluation done at random point.
# Time taken: 8.6598
# Function value obtained: -0.5652
# Current minimum: -0.6377
# Iteration No: 62 started. Evaluating function at random point.
# 0.5754699423041132 0.391304347826087 0.42028985507246375
# Iteration No: 62 ended. Evaluation done at random point.
# Time taken: 3.0772
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 63 started. Evaluating function at random point.
# 0.5051570020628008 0.43478260869565216 0.463768115942029
# Iteration No: 63 ended. Evaluation done at random point.
# Time taken: 4.5210
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 64 started. Evaluating function at random point.
# 0.5163152053274139 0.42028985507246375 0.42028985507246375
# Iteration No: 64 ended. Evaluation done at random point.
# Time taken: 12.1221
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 65 started. Evaluating function at random point.
# 0.5760787282361847 0.4057971014492754 0.4492753623188406
# Iteration No: 65 ended. Evaluation done at random point.
# Time taken: 6.1875
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 66 started. Evaluating function at random point.
# 0.4933396764985728 0.5217391304347826 0.5942028985507246
# Iteration No: 66 ended. Evaluation done at random point.
# Time taken: 2.3300
# Function value obtained: -0.5942
# Current minimum: -0.6377
# Iteration No: 67 started. Evaluating function at random point.
# 0.4882958801498128 0.463768115942029 0.5217391304347826
# Iteration No: 67 ended. Evaluation done at random point.
# Time taken: 8.6830
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 68 started. Evaluating function at random point.
# 0.5281120105009844 0.5072463768115942 0.5217391304347826
# Iteration No: 68 ended. Evaluation done at random point.
# Time taken: 4.6004
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 69 started. Evaluating function at random point.
# 0.4913772738010867 0.43478260869565216 0.4927536231884058
# Iteration No: 69 ended. Evaluation done at random point.
# Time taken: 12.1076
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 70 started. Evaluating function at random point.
# 0.5289185121479252 0.43478260869565216 0.5072463768115942
# Iteration No: 70 ended. Evaluation done at random point.
# Time taken: 4.7741
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 71 started. Evaluating function at random point.
# 0.5059914085462356 0.43478260869565216 0.463768115942029
# Iteration No: 71 ended. Evaluation done at random point.
# Time taken: 7.3442
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 72 started. Evaluating function at random point.
# 0.49025202092249165 0.5362318840579711 0.4782608695652174
# Iteration No: 72 ended. Evaluation done at random point.
# Time taken: 3.1269
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 73 started. Evaluating function at random point.
# 0.49722735674676527 0.4927536231884058 0.5217391304347826
# Iteration No: 73 ended. Evaluation done at random point.
# Time taken: 7.2507
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 74 started. Evaluating function at random point.
# 0.2847222222222222 0.4057971014492754 0.391304347826087
# Iteration No: 74 ended. Evaluation done at random point.
# Time taken: 3.2224
# Function value obtained: -0.4058
# Current minimum: -0.6377
# Iteration No: 75 started. Evaluating function at random point.
# 0.49789029535864976 0.43478260869565216 0.463768115942029
# Iteration No: 75 ended. Evaluation done at random point.
# Time taken: 15.4041
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 76 started. Evaluating function at random point.
# 0.4945639602128151 0.463768115942029 0.43478260869565216
# Iteration No: 76 ended. Evaluation done at random point.
# Time taken: 7.8765
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 77 started. Evaluating function at random point.
# 0.46885003693671506 0.4927536231884058 0.37681159420289856
# Iteration No: 77 ended. Evaluation done at random point.
# Time taken: 10.9180
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 78 started. Evaluating function at random point.
# 0.49 0.5507246376811594 0.5797101449275363
# Iteration No: 78 ended. Evaluation done at random point.
# Time taken: 5.7291
# Function value obtained: -0.5797
# Current minimum: -0.6377
# Iteration No: 79 started. Evaluating function at random point.
# 0.2754957507082153 0.4492753623188406 0.4492753623188406
# Iteration No: 79 ended. Evaluation done at random point.
# Time taken: 3.5104
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 80 started. Evaluating function at random point.
# 0.48909512761020885 0.43478260869565216 0.4492753623188406
# Iteration No: 80 ended. Evaluation done at random point.
# Time taken: 5.0489
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 81 started. Evaluating function at random point.
# 0.5034835113794706 0.4927536231884058 0.5652173913043478
# Iteration No: 81 ended. Evaluation done at random point.
# Time taken: 3.6244
# Function value obtained: -0.5652
# Current minimum: -0.6377
# Iteration No: 82 started. Evaluating function at random point.
# 0.5029451744449479 0.4782608695652174 0.4927536231884058
# Iteration No: 82 ended. Evaluation done at random point.
# Time taken: 8.6785
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 83 started. Evaluating function at random point.
# 0.4101573281810654 0.4057971014492754 0.4492753623188406
# Iteration No: 83 ended. Evaluation done at random point.
# Time taken: 2.9179
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 84 started. Evaluating function at random point.
# 0.3846849562858004 0.4927536231884058 0.463768115942029
# Iteration No: 84 ended. Evaluation done at random point.
# Time taken: 2.9846
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 85 started. Evaluating function at random point.
# 0.5001166316771635 0.463768115942029 0.4492753623188406
# Iteration No: 85 ended. Evaluation done at random point.
# Time taken: 11.7555
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 86 started. Evaluating function at random point.
# 0.48487781272683284 0.5362318840579711 0.5217391304347826
# Iteration No: 86 ended. Evaluation done at random point.
# Time taken: 2.4341
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 87 started. Evaluating function at random point.
# 0.5111111111111112 0.4927536231884058 0.4927536231884058
# Iteration No: 87 ended. Evaluation done at random point.
# Time taken: 6.7855
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 88 started. Evaluating function at random point.
# 0.5247164562379628 0.4782608695652174 0.43478260869565216
# Iteration No: 88 ended. Evaluation done at random point.
# Time taken: 6.0164
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 89 started. Evaluating function at random point.
# 0.4950773558368495 0.4492753623188406 0.43478260869565216
# Iteration No: 89 ended. Evaluation done at random point.
# Time taken: 2.8264
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 90 started. Evaluating function at random point.
# 0.4983544898918664 0.4492753623188406 0.4492753623188406
# Iteration No: 90 ended. Evaluation done at random point.
# Time taken: 7.1433
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 91 started. Evaluating function at random point.
# 0.49882794186591656 0.4492753623188406 0.5072463768115942
# Iteration No: 91 ended. Evaluation done at random point.
# Time taken: 6.3124
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 92 started. Evaluating function at random point.
# 0.5841363973313566 0.42028985507246375 0.4492753623188406
# Iteration No: 92 ended. Evaluation done at random point.
# Time taken: 2.5976
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 93 started. Evaluating function at random point.
# 0.38859494415049967 0.43478260869565216 0.463768115942029
# Iteration No: 93 ended. Evaluation done at random point.
# Time taken: 4.9931
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 94 started. Evaluating function at random point.
# 0.4706748466257668 0.4782608695652174 0.391304347826087
# Iteration No: 94 ended. Evaluation done at random point.
# Time taken: 10.1434
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 95 started. Evaluating function at random point.
# 0.5002359603586598 0.463768115942029 0.5072463768115942
# Iteration No: 95 ended. Evaluation done at random point.
# Time taken: 5.1383
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 96 started. Evaluating function at random point.
# 0.1865580448065173 0.391304347826087 0.42028985507246375
# Iteration No: 96 ended. Evaluation done at random point.
# Time taken: 4.4801
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 97 started. Evaluating function at random point.
# 0.6185027786858451 0.43478260869565216 0.37681159420289856
# Iteration No: 97 ended. Evaluation done at random point.
# Time taken: 3.9940
# Function value obtained: -0.4348
# Current minimum: -0.6377
# Iteration No: 98 started. Evaluating function at random point.
# 0.49362096961261887 0.42028985507246375 0.5652173913043478
# Iteration No: 98 ended. Evaluation done at random point.
# Time taken: 10.3275
# Function value obtained: -0.5652
# Current minimum: -0.6377
# Iteration No: 99 started. Evaluating function at random point.
# 0.38901869158878505 0.43478260869565216 0.463768115942029
# Iteration No: 99 ended. Evaluation done at random point.
# Time taken: 2.6333
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 100 started. Evaluating function at random point.
# 0.4841906559697971 0.42028985507246375 0.4927536231884058
# Iteration No: 100 ended. Evaluation done at random point.
# Time taken: 9.6596
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 101 started. Evaluating function at random point.
# 0.5150636018745816 0.5072463768115942 0.5072463768115942
# Iteration No: 101 ended. Evaluation done at random point.
# Time taken: 19.5863
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 102 started. Evaluating function at random point.
# 0.49683618467307245 0.43478260869565216 0.463768115942029
# Iteration No: 102 ended. Evaluation done at random point.
# Time taken: 15.8805
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 103 started. Evaluating function at random point.
# 0.4876291136199856 0.5652173913043478 0.5797101449275363
# Iteration No: 103 ended. Evaluation done at random point.
# Time taken: 14.5174
# Function value obtained: -0.5797
# Current minimum: -0.6377
# Iteration No: 104 started. Evaluating function at random point.
# 0.5107650022904261 0.5217391304347826 0.5362318840579711
# Iteration No: 104 ended. Evaluation done at random point.
# Time taken: 4.4561
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 105 started. Evaluating function at random point.
# 0.48197343453510433 0.37681159420289856 0.4492753623188406
# Iteration No: 105 ended. Evaluation done at random point.
# Time taken: 4.6452
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 106 started. Evaluating function at random point.
# 0.5016241299303944 0.4492753623188406 0.5072463768115942
# Iteration No: 106 ended. Evaluation done at random point.
# Time taken: 5.2771
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 107 started. Evaluating function at random point.
# 0.5076466560146085 0.4492753623188406 0.4492753623188406
# Iteration No: 107 ended. Evaluation done at random point.
# Time taken: 6.9200
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 108 started. Evaluating function at random point.
# 0.3859964093357271 0.5072463768115942 0.5362318840579711
# Iteration No: 108 ended. Evaluation done at random point.
# Time taken: 10.4778
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 109 started. Evaluating function at random point.
# 0.4931050879695673 0.5362318840579711 0.5942028985507246
# Iteration No: 109 ended. Evaluation done at random point.
# Time taken: 4.4682
# Function value obtained: -0.5942
# Current minimum: -0.6377
# Iteration No: 110 started. Evaluating function at random point.
# 0.496538994000923 0.463768115942029 0.42028985507246375
# Iteration No: 110 ended. Evaluation done at random point.
# Time taken: 3.6768
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 111 started. Evaluating function at random point.
# 0.49584421752552843 0.5217391304347826 0.5507246376811594
# Iteration No: 111 ended. Evaluation done at random point.
# Time taken: 2.6462
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 112 started. Evaluating function at random point.
# 0.546166529266282 0.463768115942029 0.5217391304347826
# Iteration No: 112 ended. Evaluation done at random point.
# Time taken: 4.6746
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 113 started. Evaluating function at random point.
# 0.5093984962406014 0.5072463768115942 0.4782608695652174
# Iteration No: 113 ended. Evaluation done at random point.
# Time taken: 5.1541
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 114 started. Evaluating function at random point.
# 0.47596382674916704 0.43478260869565216 0.4492753623188406
# Iteration No: 114 ended. Evaluation done at random point.
# Time taken: 17.0254
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 115 started. Evaluating function at random point.
# 0.4777025449451319 0.37681159420289856 0.391304347826087
# Iteration No: 115 ended. Evaluation done at random point.
# Time taken: 6.6416
# Function value obtained: -0.3913
# Current minimum: -0.6377
# Iteration No: 116 started. Evaluating function at random point.
# 0.5090579710144928 0.5362318840579711 0.5507246376811594
# Iteration No: 116 ended. Evaluation done at random point.
# Time taken: 9.6255
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 117 started. Evaluating function at random point.
# 0.5287746867700148 0.43478260869565216 0.4492753623188406
# Iteration No: 117 ended. Evaluation done at random point.
# Time taken: 13.1018
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 118 started. Evaluating function at random point.
# 0.5818789454140364 0.4492753623188406 0.43478260869565216
# Iteration No: 118 ended. Evaluation done at random point.
# Time taken: 7.2048
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 119 started. Evaluating function at random point.
# 0.4982554082344732 0.4782608695652174 0.5652173913043478
# Iteration No: 119 ended. Evaluation done at random point.
# Time taken: 13.9914
# Function value obtained: -0.5652
# Current minimum: -0.6377
# Iteration No: 120 started. Evaluating function at random point.
# 0.4958910542380841 0.5217391304347826 0.5507246376811594
# Iteration No: 120 ended. Evaluation done at random point.
# Time taken: 6.6481
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 121 started. Evaluating function at random point.
# 0.4418481147105683 0.4782608695652174 0.4782608695652174
# Iteration No: 121 ended. Evaluation done at random point.
# Time taken: 3.0031
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 122 started. Evaluating function at random point.
# 0.5342293154136917 0.463768115942029 0.463768115942029
# Iteration No: 122 ended. Evaluation done at random point.
# Time taken: 3.7265
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 123 started. Evaluating function at random point.
# 0.48534754177767014 0.5507246376811594 0.5507246376811594
# Iteration No: 123 ended. Evaluation done at random point.
# Time taken: 2.1737
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 124 started. Evaluating function at random point.
# 0.5069962686567164 0.4782608695652174 0.5362318840579711
# Iteration No: 124 ended. Evaluation done at random point.
# Time taken: 7.9412
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 125 started. Evaluating function at random point.
# 0.5007006071929005 0.43478260869565216 0.5072463768115942
# Iteration No: 125 ended. Evaluation done at random point.
# Time taken: 4.3716
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 126 started. Evaluating function at random point.
# 0.5029775538250114 0.37681159420289856 0.463768115942029
# Iteration No: 126 ended. Evaluation done at random point.
# Time taken: 3.3817
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 127 started. Evaluating function at random point.
# 0.5 0.42028985507246375 0.5217391304347826
# Iteration No: 127 ended. Evaluation done at random point.
# Time taken: 6.2475
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 128 started. Evaluating function at random point.
# 0.5042016806722689 0.5217391304347826 0.5362318840579711
# Iteration No: 128 ended. Evaluation done at random point.
# Time taken: 9.0709
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 129 started. Evaluating function at random point.
# 0.5360691144708423 0.4927536231884058 0.5072463768115942
# Iteration No: 129 ended. Evaluation done at random point.
# Time taken: 5.6553
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 130 started. Evaluating function at random point.
# 0.49533146591970123 0.4782608695652174 0.36231884057971014
# Iteration No: 130 ended. Evaluation done at random point.
# Time taken: 10.5006
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 131 started. Evaluating function at random point.
# 0.5151245551601423 0.4057971014492754 0.463768115942029
# Iteration No: 131 ended. Evaluation done at random point.
# Time taken: 13.0239
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 132 started. Evaluating function at random point.
# 0.4960666358167515 0.4492753623188406 0.463768115942029
# Iteration No: 132 ended. Evaluation done at random point.
# Time taken: 12.4901
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 133 started. Evaluating function at random point.
# 0.4922788956481048 0.5072463768115942 0.5072463768115942
# Iteration No: 133 ended. Evaluation done at random point.
# Time taken: 5.8850
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 134 started. Evaluating function at random point.
# 0.4940898345153664 0.4927536231884058 0.5217391304347826
# Iteration No: 134 ended. Evaluation done at random point.
# Time taken: 12.9230
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 135 started. Evaluating function at random point.
# 0.48315688161693937 0.5362318840579711 0.5507246376811594
# Iteration No: 135 ended. Evaluation done at random point.
# Time taken: 7.5331
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 136 started. Evaluating function at random point.
# 0.49571064224437744 0.463768115942029 0.5072463768115942
# Iteration No: 136 ended. Evaluation done at random point.
# Time taken: 7.8371
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 137 started. Evaluating function at random point.
# 0.5882996172772006 0.42028985507246375 0.42028985507246375
# Iteration No: 137 ended. Evaluation done at random point.
# Time taken: 3.3889
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 138 started. Evaluating function at random point.
# 0.49187180678123543 0.4492753623188406 0.4927536231884058
# Iteration No: 138 ended. Evaluation done at random point.
# Time taken: 9.0304
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 139 started. Evaluating function at random point.
# 0.5343251859723698 0.463768115942029 0.463768115942029
# Iteration No: 139 ended. Evaluation done at random point.
# Time taken: 5.4202
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 140 started. Evaluating function at random point.
# 0.05222437137330754 0.43478260869565216 0.4927536231884058
# Iteration No: 140 ended. Evaluation done at random point.
# Time taken: 3.6883
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 141 started. Evaluating function at random point.
# 0.4931899641577061 0.6086956521739131 0.5942028985507246
# Iteration No: 141 ended. Evaluation done at random point.
# Time taken: 2.2791
# Function value obtained: -0.6087
# Current minimum: -0.6377
# Iteration No: 142 started. Evaluating function at random point.
# 0.49011299435028244 0.4927536231884058 0.5797101449275363
# Iteration No: 142 ended. Evaluation done at random point.
# Time taken: 6.1875
# Function value obtained: -0.5797
# Current minimum: -0.6377
# Iteration No: 143 started. Evaluating function at random point.
# 0.48455056179775274 0.34782608695652173 0.463768115942029
# Iteration No: 143 ended. Evaluation done at random point.
# Time taken: 3.1077
# Function value obtained: -0.4638
# Current minimum: -0.6377
# Iteration No: 144 started. Evaluating function at random point.
# 0.5756676557863502 0.36231884057971014 0.42028985507246375
# Iteration No: 144 ended. Evaluation done at random point.
# Time taken: 3.0561
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 145 started. Evaluating function at random point.
# 0.49953617810760664 0.43478260869565216 0.4492753623188406
# Iteration No: 145 ended. Evaluation done at random point.
# Time taken: 6.7305
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 146 started. Evaluating function at random point.
# 0.49656153663742 0.5362318840579711 0.5362318840579711
# Iteration No: 146 ended. Evaluation done at random point.
# Time taken: 2.5389
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 147 started. Evaluating function at random point.
# 0.5822454308093995 0.463768115942029 0.5072463768115942
# Iteration No: 147 ended. Evaluation done at random point.
# Time taken: 5.2253
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 148 started. Evaluating function at random point.
# 0.4636955433149724 0.43478260869565216 0.36231884057971014
# Iteration No: 148 ended. Evaluation done at random point.
# Time taken: 14.1130
# Function value obtained: -0.4348
# Current minimum: -0.6377
# Iteration No: 149 started. Evaluating function at random point.
# 0.49176414418715686 0.5072463768115942 0.5362318840579711
# Iteration No: 149 ended. Evaluation done at random point.
# Time taken: 6.2019
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 150 started. Evaluating function at random point.
# 0.4987182474947565 0.463768115942029 0.5507246376811594
# Iteration No: 150 ended. Evaluation done at random point.
# Time taken: 4.7384
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 151 started. Evaluating function at random point.
# 0.49122807017543857 0.4782608695652174 0.5507246376811594
# Iteration No: 151 ended. Evaluation done at random point.
# Time taken: 5.7825
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 152 started. Evaluating function at random point.
# 0.4877117633023145 0.4492753623188406 0.5942028985507246
# Iteration No: 152 ended. Evaluation done at random point.
# Time taken: 2.8684
# Function value obtained: -0.5942
# Current minimum: -0.6377
# Iteration No: 153 started. Evaluating function at random point.
# 0.49060195098738996 0.4927536231884058 0.6086956521739131
# Iteration No: 153 ended. Evaluation done at random point.
# Time taken: 4.4330
# Function value obtained: -0.6087
# Current minimum: -0.6377
# Iteration No: 154 started. Evaluating function at random point.
# 0.07047619047619047 0.42028985507246375 0.4492753623188406
# Iteration No: 154 ended. Evaluation done at random point.
# Time taken: 2.7940
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 155 started. Evaluating function at random point.
# 0.4812382739212007 0.36231884057971014 0.4492753623188406
# Iteration No: 155 ended. Evaluation done at random point.
# Time taken: 5.2041
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 156 started. Evaluating function at random point.
# 0.07566557683325548 0.43478260869565216 0.4782608695652174
# Iteration No: 156 ended. Evaluation done at random point.
# Time taken: 3.5775
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 157 started. Evaluating function at random point.
# 0.5009276437847867 0.5217391304347826 0.463768115942029
# Iteration No: 157 ended. Evaluation done at random point.
# Time taken: 5.1165
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 158 started. Evaluating function at random point.
# 0.49614576033637003 0.4782608695652174 0.4492753623188406
# Iteration No: 158 ended. Evaluation done at random point.
# Time taken: 2.8441
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 159 started. Evaluating function at random point.
# 0.5041938490214352 0.5362318840579711 0.5507246376811594
# Iteration No: 159 ended. Evaluation done at random point.
# Time taken: 8.6222
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 160 started. Evaluating function at random point.
# 0.6134595874196821 0.43478260869565216 0.5217391304347826
# Iteration No: 160 ended. Evaluation done at random point.
# Time taken: 3.4520
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 161 started. Evaluating function at random point.
# 0.6126951799049559 0.5072463768115942 0.5217391304347826
# Iteration No: 161 ended. Evaluation done at random point.
# Time taken: 3.3312
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 162 started. Evaluating function at random point.
# 0.4908118167015585 0.4782608695652174 0.4927536231884058
# Iteration No: 162 ended. Evaluation done at random point.
# Time taken: 8.1427
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 163 started. Evaluating function at random point.
# 0.48300451628238655 0.43478260869565216 0.4782608695652174
# Iteration No: 163 ended. Evaluation done at random point.
# Time taken: 4.0855
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 164 started. Evaluating function at random point.
# 0.2973158981417756 0.34782608695652173 0.42028985507246375
# Iteration No: 164 ended. Evaluation done at random point.
# Time taken: 7.6069
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 165 started. Evaluating function at random point.
# 0.531305114638448 0.4927536231884058 0.5362318840579711
# Iteration No: 165 ended. Evaluation done at random point.
# Time taken: 4.4192
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 166 started. Evaluating function at random point.
# 0.5011633317822243 0.4057971014492754 0.4492753623188406
# Iteration No: 166 ended. Evaluation done at random point.
# Time taken: 6.4521
# Function value obtained: -0.4493
# Current minimum: -0.6377
# Iteration No: 167 started. Evaluating function at random point.
# 0.49097815764482433 0.5652173913043478 0.5652173913043478
# Iteration No: 167 ended. Evaluation done at random point.
# Time taken: 8.2960
# Function value obtained: -0.5652
# Current minimum: -0.6377
# Iteration No: 168 started. Evaluating function at random point.
# 0.49276028499195584 0.4492753623188406 0.4782608695652174
# Iteration No: 168 ended. Evaluation done at random point.
# Time taken: 4.7764
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 169 started. Evaluating function at random point.
# 0.5049551675318545 0.5217391304347826 0.5217391304347826
# Iteration No: 169 ended. Evaluation done at random point.
# Time taken: 6.9161
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 170 started. Evaluating function at random point.
# 0.5851398925328887 0.37681159420289856 0.43478260869565216
# Iteration No: 170 ended. Evaluation done at random point.
# Time taken: 10.3023
# Function value obtained: -0.4348
# Current minimum: -0.6377
# Iteration No: 171 started. Evaluating function at random point.
# 0.18589482266612314 0.42028985507246375 0.4057971014492754
# Iteration No: 171 ended. Evaluation done at random point.
# Time taken: 3.9011
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 172 started. Evaluating function at random point.
# 0.508459282652831 0.5217391304347826 0.5507246376811594
# Iteration No: 172 ended. Evaluation done at random point.
# Time taken: 10.6701
# Function value obtained: -0.5507
# Current minimum: -0.6377
# Iteration No: 173 started. Evaluating function at random point.
# 0.5468908243872799 0.43478260869565216 0.43478260869565216
# Iteration No: 173 ended. Evaluation done at random point.
# Time taken: 3.9497
# Function value obtained: -0.4348
# Current minimum: -0.6377
# Iteration No: 174 started. Evaluating function at random point.
# 0.389082462253194 0.37681159420289856 0.4927536231884058
# Iteration No: 174 ended. Evaluation done at random point.
# Time taken: 2.6715
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 175 started. Evaluating function at random point.
# 0.5006960556844547 0.5362318840579711 0.463768115942029
# Iteration No: 175 ended. Evaluation done at random point.
# Time taken: 5.1882
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 176 started. Evaluating function at random point.
# 0.5022026431718062 0.43478260869565216 0.5072463768115942
# Iteration No: 176 ended. Evaluation done at random point.
# Time taken: 5.6494
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 177 started. Evaluating function at random point.
# 0.49626865671641796 0.4782608695652174 0.5217391304347826
# Iteration No: 177 ended. Evaluation done at random point.
# Time taken: 5.9292
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 178 started. Evaluating function at random point.
# 0.4882036907264658 0.5072463768115942 0.5217391304347826
# Iteration No: 178 ended. Evaluation done at random point.
# Time taken: 5.8912
# Function value obtained: -0.5217
# Current minimum: -0.6377
# Iteration No: 179 started. Evaluating function at random point.
# 0.5013927576601671 0.463768115942029 0.5072463768115942
# Iteration No: 179 ended. Evaluation done at random point.
# Time taken: 3.8710
# Function value obtained: -0.5072
# Current minimum: -0.6377
# Iteration No: 180 started. Evaluating function at random point.
# 0.49651972157772617 0.5072463768115942 0.5362318840579711
# Iteration No: 180 ended. Evaluation done at random point.
# Time taken: 9.1456
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 181 started. Evaluating function at random point.
# 0.3645615085303801 0.4782608695652174 0.4782608695652174
# Iteration No: 181 ended. Evaluation done at random point.
# Time taken: 5.3730
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 182 started. Evaluating function at random point.
# 0.49584026622296173 0.5217391304347826 0.6231884057971014
# Iteration No: 182 ended. Evaluation done at random point.
# Time taken: 2.5097
# Function value obtained: -0.6232
# Current minimum: -0.6377
# Iteration No: 183 started. Evaluating function at random point.
# 0.27527492018446253 0.37681159420289856 0.42028985507246375
# Iteration No: 183 ended. Evaluation done at random point.
# Time taken: 2.5887
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 184 started. Evaluating function at random point.
# 0.5210993291495347 0.4927536231884058 0.4782608695652174
# Iteration No: 184 ended. Evaluation done at random point.
# Time taken: 5.5455
# Function value obtained: -0.4928
# Current minimum: -0.6377
# Iteration No: 185 started. Evaluating function at random point.
# 0.513888888888889 0.4782608695652174 0.463768115942029
# Iteration No: 185 ended. Evaluation done at random point.
# Time taken: 2.6971
# Function value obtained: -0.4783
# Current minimum: -0.6377
# Iteration No: 186 started. Evaluating function at random point.
# 0.4972041006523765 0.463768115942029 0.5362318840579711
# Iteration No: 186 ended. Evaluation done at random point.
# Time taken: 4.6549
# Function value obtained: -0.5362
# Current minimum: -0.6377
# Iteration No: 187 started. Evaluating function at random point.
# 0.5027223230490019 0.4057971014492754 0.42028985507246375
# Iteration No: 187 ended. Evaluation done at random point.
# Time taken: 14.5059
# Function value obtained: -0.4203
# Current minimum: -0.6377
# Iteration No: 188 started. Evaluating function at random point.
# 0.39421128798842253 0.463768115942029 0.5217391304347826
# Iteration No: 188 ended. Evaluation done at random point.
# Time taken: 2.3186
# Function value obtained: -0.5217
# Current minimum: -0.6377
# ...
# Iteration No: 343 started. Searching for the next optimal point.
# 0.4738084001887683 0.4057971014492754 0.43478260869565216
# Iteration No: 343 ended. Search finished for the next optimal point.
# Time taken: 12.5009
# Function value obtained: -0.4348
# Current minimum: -0.6522
# Iteration No: 344 started. Searching for the next optimal point.
# 0.5183175033921303 0.5072463768115942 0.5217391304347826
# Iteration No: 344 ended. Search finished for the next optimal point.
# Time taken: 12.8870
# Function value obtained: -0.5217
# Current minimum: -0.6522
# Iteration No: 345 started. Searching for the next optimal point.
# 0.4868421052631579 0.4782608695652174 0.5942028985507246
# Iteration No: 345 ended. Search finished for the next optimal point.
# Time taken: 17.7266
# Function value obtained: -0.5942
# Current minimum: -0.6522
# Iteration No: 346 started. Searching for the next optimal point.
# 0.511690046760187 0.463768115942029 0.5217391304347826
# Iteration No: 346 ended. Search finished for the next optimal point.
# Time taken: 17.2969
# Function value obtained: -0.5217
# Current minimum: -0.6522
# Iteration No: 347 started. Searching for the next optimal point.
# 0.4915824915824916 0.5217391304347826 0.5217391304347826
# Iteration No: 347 ended. Search finished for the next optimal point.
# Time taken: 14.3367
# Function value obtained: -0.5217
# Current minimum: -0.6522
# Iteration No: 348 started. Searching for the next optimal point.
# 0.4951202094739348 0.5797101449275363 0.6086956521739131
# Iteration No: 348 ended. Search finished for the next optimal point.
# Time taken: 14.7586
# Function value obtained: -0.6087
# Current minimum: -0.6522
# Iteration No: 349 started. Searching for the next optimal point.
# 0.4859273514553764 0.463768115942029 0.5507246376811594
# Iteration No: 349 ended. Search finished for the next optimal point.
# Time taken: 15.1991
# Function value obtained: -0.5507
# Current minimum: -0.6522
# Iteration No: 350 started. Searching for the next optimal point.
# 0.49572243346007605 0.5652173913043478 0.6086956521739131
# Iteration No: 350 ended. Search finished for the next optimal point.
# Time taken: 14.0997
# Function value obtained: -0.6087
# Current minimum: -0.6522
# Iteration No: 351 started. Searching for the next optimal point.
# 0.4992927864214994 0.5652173913043478 0.5652173913043478
# Iteration No: 351 ended. Search finished for the next optimal point.
# Time taken: 21.7646
# Function value obtained: -0.5652
# Current minimum: -0.6522
# Iteration No: 352 started. Searching for the next optimal point.
# 0.4902375911550223 0.4782608695652174 0.5507246376811594
# Iteration No: 352 ended. Search finished for the next optimal point.
# Time taken: 17.2793
# Function value obtained: -0.5507
# Current minimum: -0.6522
# Iteration No: 353 started. Searching for the next optimal point.
# 0.57265625 0.4492753623188406 0.43478260869565216
# Iteration No: 353 ended. Search finished for the next optimal point.
# Time taken: 16.3415
# Function value obtained: -0.4493
# Current minimum: -0.6522
# Iteration No: 354 started. Searching for the next optimal point.
# 0.49607982893799 0.5797101449275363 0.5797101449275363
# Iteration No: 354 ended. Search finished for the next optimal point.
# Time taken: 16.1338
# Function value obtained: -0.5797
# Current minimum: -0.6522
# Iteration No: 355 started. Searching for the next optimal point.
# 0.472918157957528 0.4492753623188406 0.4492753623188406
# Iteration No: 355 ended. Search finished for the next optimal point.
# Time taken: 13.4546
# Function value obtained: -0.4493
# Current minimum: -0.6522
# Iteration No: 356 started. Searching for the next optimal point.
# 0.4886985486557221 0.5072463768115942 0.5797101449275363
# Iteration No: 356 ended. Search finished for the next optimal point.
# Time taken: 16.0630
# Function value obtained: -0.5797
# Current minimum: -0.6522
# Iteration No: 357 started. Searching for the next optimal point.
# 0.49140401146131807 0.5797101449275363 0.6666666666666666
# Iteration No: 357 ended. Search finished for the next optimal point.
# Time taken: 13.4324
# Function value obtained: -0.6667
# Current minimum: -0.6667
# Iteration No: 358 started. Searching for the next optimal point.
# 0.49282982791586993 0.5652173913043478 0.6231884057971014
# Iteration No: 358 ended. Search finished for the next optimal point.
# Time taken: 15.2849
# Function value obtained: -0.6232
# Current minimum: -0.6667
# Iteration No: 359 started. Searching for the next optimal point.
# 0.49488460623364267 0.5652173913043478 0.6086956521739131
# Iteration No: 359 ended. Search finished for the next optimal point.
# Time taken: 15.4290
# Function value obtained: -0.6087
# Current minimum: -0.6667
# Iteration No: 360 started. Searching for the next optimal point.
# 0.4930721452460583 0.5652173913043478 0.6231884057971014
# Iteration No: 360 ended. Search finished for the next optimal point.
# Time taken: 15.7771
# Function value obtained: -0.6232
# Current minimum: -0.6667
# Iteration No: 361 started. Searching for the next optimal point.
# 0.5025569502556949 0.463768115942029 0.5072463768115942
# Iteration No: 361 ended. Search finished for the next optimal point.
# Time taken: 15.0907
# Function value obtained: -0.5072
# Current minimum: -0.6667
# Iteration No: 362 started. Searching for the next optimal point.
# 0.49548264384213025 0.5652173913043478 0.6086956521739131
# Iteration No: 362 ended. Search finished for the next optimal point.
# Time taken: 16.0624
# Function value obtained: -0.6087
# Current minimum: -0.6667
# Iteration No: 363 started. Searching for the next optimal point.
# 0.49145299145299143 0.5217391304347826 0.5797101449275363
# Iteration No: 363 ended. Search finished for the next optimal point.
# Time taken: 24.2467
# Function value obtained: -0.5797
# Current minimum: -0.6667
# Iteration No: 364 started. Searching for the next optimal point.
# 0.49743589743589745 0.5217391304347826 0.5507246376811594
# Iteration No: 364 ended. Search finished for the next optimal point.
# Time taken: 27.5060
# Function value obtained: -0.5507
# Current minimum: -0.6667
# Iteration No: 365 started. Searching for the next optimal point.
# 0.4941457586618877 0.5652173913043478 0.6231884057971014
# Iteration No: 365 ended. Search finished for the next optimal point.
# Time taken: 17.7121
# Function value obtained: -0.6232
# Current minimum: -0.6667
# Iteration No: 366 started. Searching for the next optimal point.
# 0.49205972979379 0.5072463768115942 0.5797101449275363
# Iteration No: 366 ended. Search finished for the next optimal point.
# Time taken: 24.3769
# Function value obtained: -0.5797
# Current minimum: -0.6667
# Iteration No: 367 started. Searching for the next optimal point.
# 0.4929611071343355 0.5072463768115942 0.5217391304347826
# Iteration No: 367 ended. Search finished for the next optimal point.
# Time taken: 21.2089
# Function value obtained: -0.5217
# Current minimum: -0.6667
# Iteration No: 368 started. Searching for the next optimal point.
# 0.4936859661663093 0.5217391304347826 0.6231884057971014
# Iteration No: 368 ended. Search finished for the next optimal point.
# Time taken: 17.7848
# Function value obtained: -0.6232
# Current minimum: -0.6667
# Iteration No: 369 started. Searching for the next optimal point.
# 0.5104525614518722 0.5072463768115942 0.5507246376811594
# Iteration No: 369 ended. Search finished for the next optimal point.
# Time taken: 17.6564
# Function value obtained: -0.5507
# Current minimum: -0.6667
# Iteration No: 370 started. Searching for the next optimal point.
# 0.4938388625592417 0.4782608695652174 0.5652173913043478
# Iteration No: 370 ended. Search finished for the next optimal point.
# Time taken: 22.1576
# Function value obtained: -0.5652
# Current minimum: -0.6667
# Iteration No: 371 started. Searching for the next optimal point.
# 0.5229437229437229 0.463768115942029 0.4782608695652174
# Iteration No: 371 ended. Search finished for the next optimal point.
# Time taken: 18.5450
# Function value obtained: -0.4783
# Current minimum: -0.6667
# Iteration No: 372 started. Searching for the next optimal point.
# 0.5012811553692057 0.4782608695652174 0.5507246376811594
# Iteration No: 372 ended. Search finished for the next optimal point.
# Time taken: 17.2740
# Function value obtained: -0.5507
# Current minimum: -0.6667
# Iteration No: 373 started. Searching for the next optimal point.
# 0.4926559113893571 0.5797101449275363 0.5362318840579711
# Iteration No: 373 ended. Search finished for the next optimal point.
# Time taken: 17.9773
# Function value obtained: -0.5797
# Current minimum: -0.6667
# Iteration No: 374 started. Searching for the next optimal point.
# 0.5524772497472195 0.4492753623188406 0.463768115942029
# Iteration No: 374 ended. Search finished for the next optimal point.
# Time taken: 18.6671
# Function value obtained: -0.4638
# Current minimum: -0.6667
# Iteration No: 375 started. Searching for the next optimal point.
# a:\program files\python38\lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# 0.49583234103357937 0.5507246376811594 0.6376811594202898
# Iteration No: 375 ended. Search finished for the next optimal point.
# Time taken: 17.8290
# Function value obtained: -0.6377
# Current minimum: -0.6667
# Iteration No: 376 started. Searching for the next optimal point.
# 0.4894613583138174 0.4492753623188406 0.5507246376811594
# Iteration No: 376 ended. Search finished for the next optimal point.
# Time taken: 30.4304
# Function value obtained: -0.5507
# Current minimum: -0.6667
# Iteration No: 377 started. Searching for the next optimal point.
# 0.4930721452460583 0.5652173913043478 0.6231884057971014
# Iteration No: 377 ended. Search finished for the next optimal point.
# Time taken: 17.6659
# Function value obtained: -0.6232
# Current minimum: -0.6667
# Iteration No: 378 started. Searching for the next optimal point.
# a:\program files\python38\lib\site-packages\skopt\optimizer\optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# 0.49583234103357937 0.5507246376811594 0.6376811594202898
# Iteration No: 378 ended. Search finished for the next optimal point.
# Time taken: 18.1224
# Function value obtained: -0.6377
# Current minimum: -0.6667
# Iteration No: 379 started. Searching for the next optimal point.
# 0.4899328859060403 0.5362318840579711 0.5652173913043478
# Iteration No: 379 ended. Search finished for the next optimal point.
# Time taken: 20.5116
# Function value obtained: -0.5652
# Current minimum: -0.6667
# Iteration No: 380 started. Searching for the next optimal point.
# 0.5044796691936596 0.4927536231884058 0.5797101449275363
# Iteration No: 380 ended. Search finished for the next optimal point.
# Time taken: 25.4282
# Function value obtained: -0.5797
# Current minimum: -0.6667
# Iteration No: 381 started. Searching for the next optimal point.
# 0.614680398888344 0.43478260869565216 0.43478260869565216
# Iteration No: 381 ended. Search finished for the next optimal point.
# Time taken: 17.2804
# Function value obtained: -0.4348
# Current minimum: -0.6667
# Iteration No: 382 started. Searching for the next optimal point.
# 0.518783542039356 0.5072463768115942 0.4782608695652174
# Iteration No: 382 ended. Search finished for the next optimal point.
# Time taken: 22.2774
# Function value obtained: -0.5072
# Current minimum: -0.6667
# Iteration No: 383 started. Searching for the next optimal point.
# 0.4979805179377525 0.5652173913043478 0.6376811594202898
# Iteration No: 383 ended. Search finished for the next optimal point.
# Time taken: 20.8969
# Function value obtained: -0.6377
# Current minimum: -0.6667
# Iteration No: 384 started. Searching for the next optimal point.
# 0.4855328158080452 0.463768115942029 0.5507246376811594
# Iteration No: 384 ended. Search finished for the next optimal point.
# Time taken: 26.4343
# Function value obtained: -0.5507
# Current minimum: -0.6667
# Iteration No: 385 started. Searching for the next optimal point.
# 0.4929476452306957 0.5652173913043478 0.6231884057971014
# Iteration No: 385 ended. Search finished for the next optimal point.
# Time taken: 25.8281
# Function value obtained: -0.6232
# Current minimum: -0.6667
# Iteration No: 386 started. Searching for the next optimal point.
# 0.1552981552981553 0.43478260869565216 0.4782608695652174
# Iteration No: 386 ended. Search finished for the next optimal point.
# Time taken: 20.2336
# Function value obtained: -0.4783
# Current minimum: -0.6667
# Iteration No: 387 started. Searching for the next optimal point.
# 0.49523809523809526 0.5507246376811594 0.6376811594202898
# Iteration No: 387 ended. Search finished for the next optimal point.
# Time taken: 17.4471
# Function value obtained: -0.6377
# Current minimum: -0.6667
# Iteration No: 388 started. Searching for the next optimal point.
# 0.48140994688556255 0.5072463768115942 0.5362318840579711
# Iteration No: 388 ended. Search finished for the next optimal point.
# Time taken: 25.4493
# Function value obtained: -0.5362
# Current minimum: -0.6667
# Iteration No: 389 started. Searching for the next optimal point.
# 0.4941901825942613 0.5217391304347826 0.5797101449275363
# Iteration No: 389 ended. Search finished for the next optimal point.
# Time taken: 21.9276
# Function value obtained: -0.5797
# Current minimum: -0.6667
# Iteration No: 390 started. Searching for the next optimal point.
# 0.48398058252427184 0.4782608695652174 0.5217391304347826
# Iteration No: 390 ended. Search finished for the next optimal point.
# Time taken: 20.6943
# Function value obtained: -0.5217
# Current minimum: -0.6667
# Iteration No: 391 started. Searching for the next optimal point.
# 0.5053563111318118 0.5072463768115942 0.4927536231884058
# Iteration No: 391 ended. Search finished for the next optimal point.
# Time taken: 18.2480
# Function value obtained: -0.5072
# Current minimum: -0.6667
# Iteration No: 392 started. Searching for the next optimal point.
# 0.426220515633571 0.4927536231884058 0.5507246376811594
# Iteration No: 392 ended. Search finished for the next optimal point.
# Time taken: 19.1217
# Function value obtained: -0.5507
# Current minimum: -0.6667
# Iteration No: 393 started. Searching for the next optimal point.
# 0.4942583732057416 0.5942028985507246 0.6376811594202898
# Iteration No: 393 ended. Search finished for the next optimal point.
# Time taken: 19.5890
# Function value obtained: -0.6377
# Current minimum: -0.6667
# Iteration No: 394 started. Searching for the next optimal point.
# 0.498220640569395 0.5652173913043478 0.6231884057971014
# Iteration No: 394 ended. Search finished for the next optimal point.
# Time taken: 19.6413
# Function value obtained: -0.6232
# Current minimum: -0.6667
# Iteration No: 395 started. Searching for the next optimal point.
# 0.4948797332698262 0.5072463768115942 0.6376811594202898
# Iteration No: 395 ended. Search finished for the next optimal point.
# Time taken: 20.7950
# Function value obtained: -0.6377
# Current minimum: -0.6667
# Iteration No: 396 started. Searching for the next optimal point.
# 0.496308644915456 0.5942028985507246 0.6086956521739131
# Iteration No: 396 ended. Search finished for the next optimal point.
# Time taken: 19.2689
# Function value obtained: -0.6087
# Current minimum: -0.6667
# Iteration No: 397 started. Searching for the next optimal point.
# 0.4960723637229231 0.5652173913043478 0.6376811594202898
# Iteration No: 397 ended. Search finished for the next optimal point.
# Time taken: 19.0909
# Function value obtained: -0.6377
# Current minimum: -0.6667
# Iteration No: 398 started. Searching for the next optimal point.
# 0.4967849487973327 0.5362318840579711 0.6231884057971014
# Iteration No: 398 ended. Search finished for the next optimal point.
# Time taken: 18.6738
# Function value obtained: -0.6232
# Current minimum: -0.6667
# Iteration No: 399 started. Searching for the next optimal point.
# 0.4933523266856601 0.5362318840579711 0.5942028985507246
# Iteration No: 399 ended. Search finished for the next optimal point.
# Time taken: 21.2911
# Function value obtained: -0.5942
# Current minimum: -0.6667
# Iteration No: 400 started. Searching for the next optimal point.
# 0.49690623512613047 0.5797101449275363 0.6086956521739131
# Iteration No: 400 ended. Search finished for the next optimal point.
# Time taken: 22.3471
# Function value obtained: -0.6087
# Current minimum: -0.6667

# %%
joblib.dump(result, 'result.sav')
# Out:
# ['result.sav']

# %%
best_param
# Out:
# [False, True, '11', True, None, False, 'balanced', 2.7506158292731357]

# %%
a=[len(i) for i in day_x_test]

# %%
[i for i in a if i<20]
# Out:
# [14, 13, 14, 9, 14, 8, 18, 18]
